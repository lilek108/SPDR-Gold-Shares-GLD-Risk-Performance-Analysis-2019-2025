# %%
import yfinance as yf
import pandas as pd
import numpy as np

# %%
#defining tickers and date interval
tickers = {'GLD':'GLD', 'DXY':'DX-Y.NYB', 'TNX':'^TNX', 'GSPC':'^GSPC'}
start_date = '2019-01-01'
end_date = '2026-01-01'

# %%
#loading data from yahoo!finance
def download_ticker(ticker):
    df = yf.download(ticker, start=start_date, end=end_date, progress=False, auto_adjust=True)
    df.to_csv(f'/Users/mihailborisov/Desktop/gold/raw data/{ticker}_data.csv', index=True, index_label='Date', encoding='utf-8')
    return df

# %%
#getting data
dfs = {name: download_ticker(t) for name, t in tickers.items()}

# %%
#dataframe overview
def information(df):
    print(df.head(5))
    print(df.tail(5))
    print("NaN values: ",df[df.isna().any(axis=1)])
    print("Duplicates: ",df.duplicated().any())
    return df.info()

# %%
#getting overview of dataframes
for t in dfs.keys():
    print(f'Ticker {t}')
    information(dfs[t])
    print(' ')
# Out:
# Ticker GLD
# Price            Close        High         Low        Open    Volume
# Ticker             GLD         GLD         GLD         GLD       GLD
# Date
# 2019-01-02  121.330002  121.750000  120.879997  121.349998  12776200
# 2019-01-03  122.430000  122.459999  121.730003  121.779999  15440800
# 2019-01-04  121.440002  121.599998  120.690002  121.320000  13334000
# 2019-01-07  121.860001  122.220001  121.570000  122.160004   7473600
# 2019-01-08  121.529999  121.709999  121.059998  121.150002   7643100
# Price            Close        High         Low        Open    Volume
# Ticker             GLD         GLD         GLD         GLD       GLD
# Date
# 2025-12-24  411.929993  412.630005  408.829987  412.250000   6718400
# 2025-12-26  416.739990  418.450012  414.750000  416.480011  10476200
# 2025-12-29  398.600006  403.760010  395.329987  403.660004  20679200
# 2025-12-30  398.890015  403.799988  398.559998  403.600006  10179000
# 2025-12-31  396.309998  400.130005  395.589996  398.600006  10194700
# NaN values:  Empty DataFrame
# Columns: [(Close, GLD), (High, GLD), (Low, GLD), (Open, GLD), (Volume, GLD)]
# Index: []
# Duplicates:  False
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1760 entries, 2019-01-02 to 2025-12-31
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   (Close, GLD)   1760 non-null   float64
#  1   (High, GLD)    1760 non-null   float64
#  2   (Low, GLD)     1760 non-null   float64
#  3   (Open, GLD)    1760 non-null   float64
#  4   (Volume, GLD)  1760 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 82.5 KB
#
# Ticker DXY
# Price           Close       High        Low       Open   Volume
# Ticker       DX-Y.NYB   DX-Y.NYB   DX-Y.NYB   DX-Y.NYB DX-Y.NYB
# Date
# 2019-01-02  96.820000  96.959999  95.820000  96.139999        0
# 2019-01-03  96.309998  96.750000  96.209999  96.720001        0
# 2019-01-04  96.190002  96.610001  96.050003  96.279999        0
# 2019-01-07  95.709999  96.160004  95.639999  96.160004        0
# 2019-01-08  95.900002  96.029999  95.680000  95.690002        0
# Price           Close       High        Low       Open   Volume
# Ticker       DX-Y.NYB   DX-Y.NYB   DX-Y.NYB   DX-Y.NYB DX-Y.NYB
# Date
# 2025-12-24  97.980003  98.010002  97.750000  97.889999        0
# 2025-12-26  98.019997  98.129997  97.860001  97.919998        0
# 2025-12-29  98.040001  98.180000  97.919998  98.050003        0
# 2025-12-30  98.239998  98.269997  97.940002  98.010002        0
# 2025-12-31  98.279999  98.500000  98.180000  98.250000        0
# NaN values:  Empty DataFrame
# Columns: [(Close, DX-Y.NYB), (High, DX-Y.NYB), (Low, DX-Y.NYB), (Open, DX-Y.NYB), (Volume, DX-Y.NYB)]
# Index: []
# Duplicates:  False
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1762 entries, 2019-01-02 to 2025-12-31
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   (Close, DX-Y.NYB)   1762 non-null   float64
#  1   (High, DX-Y.NYB)    1762 non-null   float64
#  2   (Low, DX-Y.NYB)     1762 non-null   float64
#  3   (Open, DX-Y.NYB)    1762 non-null   float64
#  4   (Volume, DX-Y.NYB)  1762 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 82.6 KB
#
# Ticker TNX
# Price       Close   High    Low   Open Volume
# Ticker       ^TNX   ^TNX   ^TNX   ^TNX   ^TNX
# Date
# 2019-01-02  2.661  2.679  2.649  2.652      0
# 2019-01-03  2.554  2.656  2.554  2.654      0
# 2019-01-04  2.659  2.673  2.597  2.599      0
# 2019-01-07  2.682  2.687  2.632  2.634      0
# 2019-01-08  2.716  2.717  2.696  2.701      0
# Price       Close   High    Low   Open Volume
# Ticker       ^TNX   ^TNX   ^TNX   ^TNX   ^TNX
# Date
# 2025-12-24  4.136  4.167  4.132  4.167      0
# 2025-12-26  4.136  4.145  4.110  4.122      0
# 2025-12-29  4.116  4.130  4.108  4.116      0
# 2025-12-30  4.130  4.141  4.116  4.141      0
# 2025-12-31  4.163  4.173  4.126  4.126      0
# NaN values:  Empty DataFrame
# Columns: [(Close, ^TNX), (High, ^TNX), (Low, ^TNX), (Open, ^TNX), (Volume, ^TNX)]
# Index: []
# Duplicates:  False
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1760 entries, 2019-01-02 to 2025-12-31
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   (Close, ^TNX)   1760 non-null   float64
#  1   (High, ^TNX)    1760 non-null   float64
#  2   (Low, ^TNX)     1760 non-null   float64
#  3   (Open, ^TNX)    1760 non-null   float64
#  4   (Volume, ^TNX)  1760 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 82.5 KB
#
# Ticker GSPC
# Price             Close         High          Low         Open      Volume
# Ticker            ^GSPC        ^GSPC        ^GSPC        ^GSPC       ^GSPC
# Date
# 2019-01-02  2510.030029  2519.489990  2467.469971  2476.959961  3733160000
# 2019-01-03  2447.889893  2493.139893  2443.959961  2491.919922  3858830000
# 2019-01-04  2531.939941  2538.070068  2474.330078  2474.330078  4234140000
# 2019-01-07  2549.689941  2566.159912  2524.560059  2535.610107  4133120000
# 2019-01-08  2574.409912  2579.820068  2547.560059  2568.110107  4120060000
# Price             Close         High          Low         Open      Volume
# Ticker            ^GSPC        ^GSPC        ^GSPC        ^GSPC       ^GSPC
# Date
# 2025-12-24  6932.049805  6937.319824  6904.910156  6904.910156  1798270000
# 2025-12-26  6929.939941  6945.770020  6921.600098  6936.020020  2586550000
# 2025-12-29  6905.740234  6920.209961  6888.759766  6903.600098  3541750000
# 2025-12-30  6896.240234  6913.250000  6893.470215  6900.439941  3309930000
# 2025-12-31  6845.500000  6901.419922  6844.549805  6898.819824  3261830000
# NaN values:  Empty DataFrame
# Columns: [(Close, ^GSPC), (High, ^GSPC), (Low, ^GSPC), (Open, ^GSPC), (Volume, ^GSPC)]
# Index: []
# Duplicates:  False
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1760 entries, 2019-01-02 to 2025-12-31
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   (Close, ^GSPC)   1760 non-null   float64
#  1   (High, ^GSPC)    1760 non-null   float64
#  2   (Low, ^GSPC)     1760 non-null   float64
#  3   (Open, ^GSPC)    1760 non-null   float64
#  4   (Volume, ^GSPC)  1760 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 82.5 KB

# %%
def prepare_data(df):
    #droping ticker from index
    df.columns = df.columns.droplevel('Ticker')
    # adjusting dates
    df = df.sort_index()
    df.index = pd.to_datetime(df.index)
    #renaming columns to "Adjusted", because data was already adjusted (see !auto_adjust=True! in the 'loading data' step)
    for column in df.columns:
        if column != 'Volume':
            df.rename(columns={column: f'Adj {column}'}, inplace=True)
    return df

# %%
#dataframes cleaning
dfs = {k: prepare_data(v) for k,v in dfs.items()}

# %%
#calculating some metrics
def metrics_calculate(df):
    df['Return'] = df['Adj Close'].pct_change()
    df['LogReturn'] = np.log(df['Adj Close']).diff()
    df['RollVol30'] = df['Return'].rolling(30).std() * np.sqrt(252)
    df['RollMean30'] = df['Return'].rolling(30).mean() * 252
    return df

# %%
#executing calculations within dataframes
dfs = {k: metrics_calculate(v) for k,v in dfs.items()}

# %%
#saving clean data
for t in dfs.keys():
    dfs[t].to_csv(f'/Users/mihailborisov/Desktop/gold/clean data/{t}_clean.csv', index=True, index_label='Date', encoding='utf-8')

# %%
dfs
# Out:
# {'GLD': Price        Adj Close    Adj High     Adj Low    Adj Open    Volume  \
#  Date
#  2019-01-02  121.330002  121.750000  120.879997  121.349998  12776200
#  2019-01-03  122.430000  122.459999  121.730003  121.779999  15440800
#  2019-01-04  121.440002  121.599998  120.690002  121.320000  13334000
#  2019-01-07  121.860001  122.220001  121.570000  122.160004   7473600
#  2019-01-08  121.529999  121.709999  121.059998  121.150002   7643100
#  ...                ...         ...         ...         ...       ...
#  2025-12-24  411.929993  412.630005  408.829987  412.250000   6718400
#  2025-12-26  416.739990  418.450012  414.750000  416.480011  10476200
#  2025-12-29  398.600006  403.760010  395.329987  403.660004  20679200
#  2025-12-30  398.890015  403.799988  398.559998  403.600006  10179000
#  2025-12-31  396.309998  400.130005  395.589996  398.600006  10194700
#
#  Price         Return  LogReturn  RollVol30  RollMean30
#  Date
#  2019-01-02       NaN        NaN        NaN         NaN
#  2019-01-03  0.009066   0.009025        NaN         NaN
#  2019-01-04 -0.008086  -0.008119        NaN         NaN
#  2019-01-07  0.003458   0.003453        NaN         NaN
#  2019-01-08 -0.002708  -0.002712        NaN         NaN
#  ...              ...        ...        ...         ...
#  2025-12-24 -0.004134  -0.004143   0.136900    0.690555
#  2025-12-26  0.011677   0.011609   0.133702    0.653309
#  2025-12-29 -0.043528  -0.044504   0.187099    0.355570
#  2025-12-30  0.000728   0.000727   0.177814    0.513284
#  2025-12-31 -0.006468  -0.006489   0.175086    0.555250
#
#  [1760 rows x 9 columns],
#  'DXY': Price       Adj Close   Adj High    Adj Low   Adj Open  Volume    Return  \
#  Date
#  2019-01-02  96.820000  96.959999  95.820000  96.139999       0       NaN
#  2019-01-03  96.309998  96.750000  96.209999  96.720001       0 -0.005268
025-12-24  6932.049805  6937.319824  6904.910156  6904.910156  1798270000
#  2025-12-26  6929.939941  6945.770020  6921.600098  6936.020020  2586550000
#  2025-12-29  6905.740234  6920.209961  6888.759766  6903.600098  3541750000
#  2025-12-30  6896.240234  6913.250000  6893.470215  6900.439941  3309930000
#  2025-12-31  6845.500000  6901.419922  6844.549805  6898.819824  3261830000
#
#  Price         Return  LogReturn  RollVol30  RollMean30
#  Date
#  2019-01-02       NaN        NaN        NaN         NaN
#  2019-01-03 -0.024757  -0.025068        NaN         NaN
#  2019-01-04  0.034336   0.033759        NaN         NaN
#  2019-01-07  0.007010   0.006986        NaN         NaN
#  2019-01-08  0.009695   0.009649        NaN         NaN
#  ...              ...        ...        ...         ...
#  2025-12-24  0.003221   0.003216   0.123391    0.111574
#  2025-12-26 -0.000304  -0.000304   0.123408    0.103729
#  2025-12-29 -0.003492  -0.003498   0.113184    0.213473
#  2025-12-30 -0.001376  -0.001377   0.113303    0.206132
#  2025-12-31 -0.007358  -0.007385   0.112035    0.221291
#
#  [1760 rows x 9 columns]}

# %%
#creating correlation matrix for Return
assets_df = pd.DataFrame(columns=["Date", "GLD", "DXY", "TNX", "GSPC"])

# %%
for i in range(len(dfs["GLD"])):
    for asset in assets_df.columns:
        if asset == "Date":
            assets_df.loc[i, asset] = dfs["GLD"].index[i] #getting dates
        else:
            assets_df.loc[i, asset] = dfs[asset].iloc[i, -4] #getting Return values

# %%
#adjusting assets dataframe
assets_df.set_index(assets_df["Date"], inplace=True)
assets_df.drop(columns = "Date", inplace = True)
assets_df = assets_df.dropna()
# Out:
# /Users/mihailborisov/Desktop/portfolio/1(gold)/python_prep/gold_analysis/.venv/lib/python3.12/site-packages/pandas/core/indexes/base.py:7654: FutureWarning: Dtype inference on a pandas object (Series, Index, ExtensionArray) is deprecated. The Index constructor will keep the original dtype in the future. Call `infer_objects` on the result to get the old behavior.
#   return Index(sequences[0], name=names)

# %%
assets_df
# Out:
#                  GLD       DXY       TNX      GSPC
# Date
# 2019-01-03  0.009066 -0.005268  -0.04021 -0.024757
# 2019-01-04 -0.008086 -0.001246  0.041112  0.034336
# 2019-01-07  0.003458  -0.00499   0.00865   0.00701
# 2019-01-08 -0.002708  0.001985  0.012677  0.009695
# 2019-01-09  0.006418 -0.007091  0.004418  0.004098
# ...              ...       ...       ...       ...
# 2025-12-24 -0.004134 -0.003144 -0.007916  0.003221
# 2025-12-26  0.011677 -0.003561       0.0 -0.000304
# 2025-12-29 -0.043528  0.000408 -0.004836 -0.003492
# 2025-12-30  0.000728  0.000408  0.003401 -0.001376
# 2025-12-31 -0.006468  0.000204   0.00799 -0.007358
#
# [1759 rows x 4 columns]

# %%
#correlation matrix for Returns
corr_matrix = assets_df.corr()

# %%
corr_matrix
# Out:
#            GLD       DXY       TNX      GSPC
# GLD   1.000000 -0.351521 -0.262228  0.105344
# DXY  -0.351521  1.000000  0.205836 -0.166388
# TNX  -0.262228  0.205836  1.000000  0.260962
# GSPC  0.105344 -0.166388  0.260962  1.000000

# %%
corr_matrix.to_csv(f'/Users/mihailborisov/Desktop/gold/clean data/corr_matrix.csv', index=True, encoding='utf-8')
